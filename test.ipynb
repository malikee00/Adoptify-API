# %%
from db import connect_tcp_socket
import sqlalchemy

# %%
from dotenv import load_dotenv

# %%
dotenv_path = "./.env"
load_dotenv(dotenv_path=dotenv_path)
# Out:
# True

# %%
db = connect_tcp_socket()

# %%
import pandas as pd

# %%
with db.connect() as conn:
    df = pd.read_sql(
        sqlalchemy.text(
            "SELECT * FROM tbShelter"
        ),
        conn
    )
    display(df)
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# d:\PlayML\MLEnv\lib\site-packages\pymysql\connections.py in connect(self, sock)
#     643                         try:
# --> 644                             sock = socket.create_connection(
#     645                                 (self.host, self.port), self.connect_timeout, **kwargs
#
# ~\AppData\Local\Programs\Python\Python38\lib\socket.py in create_connection(address, timeout, source_address)
#     806     if err is not None:
# --> 807         raise err
#     808     else:
#
# ~\AppData\Local\Programs\Python\Python38\lib\socket.py in create_connection(address, timeout, source_address)
#     795                 sock.bind(source_address)
# --> 796             sock.connect(sa)
#     797             # Break explicitly a reference cycle
#
# ConnectionRefusedError: [WinError 10061] No connection could be made because the target machine actively refused it
#
# During handling of the above exception, another exception occurred:
#
# OperationalError                          Traceback (most recent call last)
# d:\PlayML\MLEnv\lib\site-packages\sqlalchemy\engine\base.py in __init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     144             try:
# --> 145                 self._dbapi_connection = engine.raw_connection()
#     146             except dialect.loaded_dbapi.Error as err:
#
# d:\PlayML\MLEnv\lib\site-packages\sqlalchemy\engine\base.py in raw_connection(self)
#    3274         """
# -> 3275         return self.pool.connect()
#    3276
#
# d:\PlayML\MLEnv\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     454         """
# --> 455         return _ConnectionFairy._checkout(self)
#     456
#
# d:\PlayML\MLEnv\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#    1270         if not fairy:
# -> 1271             fairy = _ConnectionRecord.checkout(pool)
#    1272
#
# d:\PlayML\MLEnv\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     718         else:
# --> 719             rec = pool._do_get()
#     720
#
# d:\PlayML\MLEnv\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     168                 with util.safe_reraise():
# --> 169                     self._dec_overflow()
#     170                 raise
#
# d:\PlayML\MLEnv\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#     146             self._exc_info = None  # remove potential circular references
# --> 147             raise exc_value.with_traceback(exc_tb)
#     148         else:
#
# d:\PlayML\MLEnv\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     165             try:
# --> 166                 return self._create_connection()
#     167             except:
#
# d:\PlayML\MLEnv\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     395
# --> 396         return _ConnectionRecord(self)
#     397
#
# d:\PlayML\MLEnv\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     680         if connect:
# --> 681             self.__connect()
#     682         self.finalize_callback = deque()
#
# d:\PlayML\MLEnv\lib\site-packages\sqlalchemy\pool\base.py in __connect(self)
#     905             with util.safe_reraise():
# --> 906                 pool.logger.debug("Error on connect(): %s", e)
#     907         else:
#
# d:\PlayML\MLEnv\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#     146             self._exc_info = None  # remove potential circular references
# --> 147             raise exc_value.with_traceback(exc_tb)
#     148         else:
#
# d:\PlayML\MLEnv\lib\site-packages\sqlalchemy\pool\base.py in __connect(self)
#     900             self.starttime = time.time()
# --> 901             self.dbapi_connection = connection = pool._invoke_creator(self)
#     902             pool.logger.debug("Created new connection %r", connection)
#
# d:\PlayML\MLEnv\lib\site-packages\sqlalchemy\engine\create.py in connect(connection_record)
#     635
# --> 636             return dialect.connect(*cargs, **cparams)
#     637
#
# d:\PlayML\MLEnv\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     579         # inherits the docstring from interfaces.Dialect.connect
# --> 580         return self.loaded_dbapi.connect(*cargs, **cparams)
#     581
#
# d:\PlayML\MLEnv\lib\site-packages\pymysql\connections.py in __init__(self, user, password, host, database, unix_socket, port, charset, collation, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, read_default_group, autocommit, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout, bind_address, binary_prefix, program_name, server_public_key, ssl, ssl_ca, ssl_cert, ssl_disabled, ssl_key, ssl_verify_cert, ssl_verify_identity, compress, named_pipe, passwd, db)
#     357         else:
# --> 358             self.connect()
#     359
#
# d:\PlayML\MLEnv\lib\site-packages\pymysql\connections.py in connect(self, sock)
#     710                     print(exc.traceback)
# --> 711                 raise exc
#     712
#
# OperationalError: (2003, "Can't connect to MySQL server on '127.0.0.1' ([WinError 10061] No connection could be made because the target machine actively refused it)")
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_25944/715485631.py in <module>
# ----> 1 with db.connect() as conn:
#       2     df = pd.read_sql(
#       3         sqlalchemy.text(
#       4             "SELECT * FROM tbShelter"
#       5         ),
#
# d:\PlayML\MLEnv\lib\site-packages\sqlalchemy\engine\base.py in connect(self)
#    3249         """
#    3250
# -> 3251         return self._connection_cls(self)
#    3252
#    3253     def raw_connection(self) -> PoolProxiedConnection:
#
# d:\PlayML\MLEnv\lib\site-packages\sqlalchemy\engine\base.py in __init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     145                 self._dbapi_connection = engine.raw_connection()
#     146             except dialect.loaded_dbapi.Error as err:
# --> 147                 Connection._handle_dbapi_exception_noconnection(
#     148                     err, dialect, engine
#     149                 )
#
# d:\PlayML\MLEnv\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine, is_disconnect, invalidate_pool_on_disconnect, is_pre_ping)
#    2411         elif should_wrap:
#    2412             assert sqlalchemy_exception is not None
# -> 2413             raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2414         else:
#    2415             assert exc_info[1] is not None
#
# d:\PlayML\MLEnv\lib\site-packages\sqlalchemy\engine\base.py in __init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     143         if connection is None:
#     144             try:
# --> 145                 self._dbapi_connection = engine.raw_connection()
#     146             except dialect.loaded_dbapi.Error as err:
#     147                 Connection._handle_dbapi_exception_noconnection(
#
# d:\PlayML\MLEnv\lib\site-packages\sqlalchemy\engine\base.py in raw_connection(self)
#    3273
#    3274         """
# -> 3275         return self.pool.connect()
#    3276
#    3277
#
# d:\PlayML\MLEnv\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     453
#     454         """
# --> 455         return _ConnectionFairy._checkout(self)
#     456
#     457     def _return_conn(self, record: ConnectionPoolEntry) -> None:
#
# d:\PlayML\MLEnv\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#    1269
#    1270         if not fairy:
# -> 1271             fairy = _ConnectionRecord.checkout(pool)
#    1272
#    1273             if threadconns is not None:
#
# d:\PlayML\MLEnv\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     717             rec = cast(_ConnectionRecord, pool._do_get())
#     718         else:
# --> 719             rec = pool._do_get()
#     720
#     721         try:
#
# d:\PlayML\MLEnv\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     167             except:
#     168                 with util.safe_reraise():
# --> 169                     self._dec_overflow()
#     170                 raise
#     171         else:
#
# d:\PlayML\MLEnv\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#     145             assert exc_value is not None
#     146             self._exc_info = None  # remove potential circular references
# --> 147             raise exc_value.with_traceback(exc_tb)
#     148         else:
#     149             self._exc_info = None  # remove potential circular references
#
# d:\PlayML\MLEnv\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     164         if self._inc_overflow():
#     165             try:
# --> 166                 return self._create_connection()
#     167             except:
#     168                 with util.safe_reraise():
#
# d:\PlayML\MLEnv\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     394         """Called by subclasses to create a new ConnectionRecord."""
#     395
# --> 396         return _ConnectionRecord(self)
#     397
#     398     def _invalidate(
#
# d:\PlayML\MLEnv\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     679         self.__pool = pool
#     680         if connect:
# --> 681             self.__connect()
#     682         self.finalize_callback = deque()
#     683
#
# d:\PlayML\MLEnv\lib\site-packages\sqlalchemy\pool\base.py in __connect(self)
#     904         except BaseException as e:
#     905             with util.safe_reraise():
# --> 906                 pool.logger.debug("Error on connect(): %s", e)
#     907         else:
#     908             # in SQLAlchemy 1.4 the first_connect event is not used by
#
# d:\PlayML\MLEnv\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#     145             assert exc_value is not None
#     146             self._exc_info = None  # remove potential circular references
# --> 147             raise exc_value.with_traceback(exc_tb)
#     148         else:
#     149             self._exc_info = None  # remove potential circular references
#
# d:\PlayML\MLEnv\lib\site-packages\sqlalchemy\pool\base.py in __connect(self)
#     899         try:
#     900             self.starttime = time.time()
# --> 901             self.dbapi_connection = connection = pool._invoke_creator(self)
#     902             pool.logger.debug("Created new connection %r", connection)
#     903             self.fresh = True
#
# d:\PlayML\MLEnv\lib\site-packages\sqlalchemy\engine\create.py in connect(connection_record)
#     634                         return connection
#     635
# --> 636             return dialect.connect(*cargs, **cparams)
#     637
#     638         creator = pop_kwarg("creator", connect)
#
# d:\PlayML\MLEnv\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     578     def connect(self, *cargs, **cparams):
#     579         # inherits the docstring from interfaces.Dialect.connect
# --> 580         return self.loaded_dbapi.connect(*cargs, **cparams)
#     581
#     582     def create_connect_args(self, url):
#
# d:\PlayML\MLEnv\lib\site-packages\pymysql\connections.py in __init__(self, user, password, host, database, unix_socket, port, charset, collation, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, read_default_group, autocommit, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout, bind_address, binary_prefix, program_name, server_public_key, ssl, ssl_ca, ssl_cert, ssl_disabled, ssl_key, ssl_verify_cert, ssl_verify_identity, compress, named_pipe, passwd, db)
#     356             self._sock = None
#     357         else:
# --> 358             self.connect()
#     359
#     360     def __enter__(self):
#
# d:\PlayML\MLEnv\lib\site-packages\pymysql\connections.py in connect(self, sock)
#     709                 if DEBUG:
#     710                     print(exc.traceback)
# --> 711                 raise exc
#     712
#     713             # If e is neither DatabaseError or IOError, It's a bug.
#
# OperationalError: (pymysql.err.OperationalError) (2003, "Can't connect to MySQL server on '127.0.0.1' ([WinError 10061] No connection could be made because the target machine actively refused it)")
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
